# %%
# run imports

import libRL
import matplotlib as mpl
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axis3d as axis3d

# %%
# execute calculation

url = 'https://raw.githubusercontent.com/1mikegrn/libRL-package/master/test/test_data.csv'

reflection_loss = libRL.reflection_loss(
        data = url,
        d_set = (1,20,0.1)
        )

# %%
# plot results

fig = plt.figure(dpi=200)
ax = fig.add_axes([-0.1,0.02,1,1], projection='3d')

ax.set_proj_type('ortho')
ax.zaxis._axinfo['juggled'] = (1,2,0)
cbaxes = fig.add_axes([0.80,0.352,0.02,0.378])

ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

ax.tick_params(axis = 'z', pad = 3)
ax.set_xlabel('Frequency / GHz', fontsize = 12)
ax.set_ylabel('Thickness / mm', fontsize = 12)
ax.view_init(-153, -130)
ax.dist=13
ax.set_yticks([0,5,10,15,20])
ax.set_yticklabels([0,5,10,15,20],va='center')
ax.set_xticks([0,5,10,15])
ax.set_xticklabels([0,5,10,15],va='center')
ax.set_zticklabels([0,-10,-20,-30,-40,-50,-60],va='center')
ax.set_zticks([0,-10,-20,-30,-40,-50,-60])
ax.set_zlim(-60,0)

ccmap = mpl.colors.ListedColormap(
       [(0,0,0),(0,0,255/255),
        (0,255/255,255/255),(0,255/255,0),
        (255/255,255/255,0),(255/255,0,0)])

plot1 = ax.plot_trisurf(
       reflection_loss[:,1],
       reflection_loss[:,2],
       reflection_loss[:,0],
       cmap=ccmap,
       linewidth=1,
       alpha=0.95,
       vmin=-60,
       vmax=0
       )

cbar1 = plt.colorbar(plot1,cax = cbaxes)
cbar1.set_ticks([])
cbar1.set_ticks([0,-10,-20,-30,-40,-50,-60])
ax.set_xlim(left = 0)
ax.set_ylim(bottom = 0) 
cbar1.ax.set_ylabel('Reflection Loss / dB',
                   fontsize = 12, labelpad = 15)

cbar1.ax.invert_yaxis()

plt.show()
